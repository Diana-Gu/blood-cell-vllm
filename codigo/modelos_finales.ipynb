# %% [markdown]
# # Multimodal Comparison (Public Version)
#
# This notebook trains and compares multimodal models using an internal reference dataset. The construction process of the reference captions is not included in the public release.

# %%
# Install
# !pip install -q transformers accelerate datasets evaluate peft pillow pandas numpy scikit-learn matplotlib tqdm

# %% [markdown]
# ## Load dataset
# Expected columns:
# - imagen
# - clase_real
# - instruction
# - reference_caption

# %%
import pandas as pd
from pathlib import Path

DATASET_PATH = Path('dataset_public.csv')
df = pd.read_csv(DATASET_PATH).fillna('')
print(df.shape)

# %% [markdown]
# ## BLIP + LoRA training (public summary)

# %%
# Model configuration
MODEL_NAME = 'Salesforce/blip-image-captioning-base'
LORA_R = 8
LORA_ALPHA = 16
EPOCHS = 3
BATCH_SIZE = 4

# %% [markdown]
# ## Inference and comparison
# Evaluate BLIP+LoRA, Gemma and Qwen outputs against the internal reference captions.

# %%
# Load predictions and compute metrics
# Implementation intentionally simplified in public version.

# %% [markdown]
# ## Results
# - Global metrics
# - Confusion matrix
# - Summary tables
